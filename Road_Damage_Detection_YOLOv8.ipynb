# %% [markdown]
# <a href="https://colab.research.google.com/github/saahilbhoir03/CODTECH-Internship/blob/main/Road_Damage_Detection_YOLOv8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU"
# Out:
# (True, 'Tesla T4')

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# Load a small YOLOv8 model
model = YOLO("yolov8n.pt")

# Run inference on a sample image
model.predict(
    source="https://ultralytics.com/images/bus.jpg",
    save=True,
    conf=0.25
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
#
# ...
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 75.3ms
# Speed: 12.1ms preprocess, 75.3ms inference, 42.4ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# !ls /content
# Out:
# bus.jpg  runs  sample_data  yolov8n.pt

# %%
# !ls /content
# Out:
# bus.jpg  runs  sample_data  yolov8n.pt

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Run detection on your uploaded road image
model.predict(
    source="/content/road.jpg",
    save=True,
    conf=0.25
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2270426756.py in <cell line: 0>()
#       5
#       6 # Run detection on your uploaded road image
# ----> 7 model.predict(
#       8     source="/content/road.jpg",
#       9     save=True,
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     534         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     535             self.predictor.set_prompts(prompts)
# --> 536         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     537
#     538     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
# ...

# %%
from ultralytics import YOLO

# Load YOLOv8 model
model = YOLO("yolov8n.pt")

# Run detection on your uploaded road image
model.predict(
    source="/road.jpg",
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /road.jpg: 416x640 6 cars, 1 truck, 85.4ms
# Speed: 2.5ms preprocess, 85.4ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 640)
# Results saved to /content/runs/detect/predict2
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...
